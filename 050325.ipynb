# %% [markdown]
# <a href="https://colab.research.google.com/github/IUBAYAR/MIS-351/blob/main/050325.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# #Simpson's Collection
# Q1: In packages containing a single random item Simpsons figures are sold for $5. Assuming each figure is equally likely, what is the probability of completing a collection of
#
#
# *   Homer Simpson,
# *   Marge Simpson,
# *   Bart Simpson,
# *   Lisa Simpson,
# *   Maggie Simpson
# *   Ned Flanders,
# *   Milhouse Van Houten,
# *   Montgomery Burns
#
# before spending $100?

# %%
sample_space = ["Homer Simpson", "Marge Simpson","Bart Simpson", "Lisa Simpson",
 "Maggie Simpson", "Ned Flanders", "Milhouse Van Houten", "Montgomery Burns"]
probabilities = [1/len(sample_space) for i in range(len(sample_space))]
# a list comprehension with 8 items values 1/8

liste = []
for i in range(10**3):
  collection =[]
  spenditure = 0

  while len(collection)< len(sample_space):
    spenditure +=5
    collection.append(np.random.choice(
                                      sample_space,
                                      p=probabilities
                                      )
    )
    #ıf you get duplicates you throw them away
    collection = list(set(collection))

  liste.append(spenditure)

# %%
liste
# Out:
# [125,
#  105,
#  65,
#  95,
#  65,
#  115,
#  85,
#  95,
#  80,
#  60,
#  160,
#  185,
#  100,
#  95,
#  90,
#  110,
#  75,
#  90,
#  95,
#  95,
#  80,
#  80,
#  200,
#  100,
#  275,
#  120,
#  75,
#  115,
#  70,
#  130,
#  110,
#  160,
#  80,
#  85,
#  165,
#  115,
#  75,
#  95,
#  175,
#  95,
#  90,
#  65,
#  120,
#  120,
#  140,
#  180,
#  80,
#  70,
#  105,
#  120,
#  80,
#  110,
#  55,
#  115,
#  65,
#  70,
#  65,
#  80,
#  75,
#  150,
#  90,
#  105,
#  70,
#  90,
#  175,
#  100,
#  120,
#  70,
#  150,
#  50,
#  215,
#  85,
#  70,
#  80,
#  105,
#  105,
#  155,
#  85,
#  65,
#  80,
#  160,
#  145,
#  70,
#  105,
#  80,
#  95,
#  150,
#  85,
#  135,
#  115,
#  150,
#  70,
#  85,
#  110,
#  115,
#  65,
#  90,
#  140,
#  130,
#  85,
#  50,
#  105,
#  180,
#  75,
#  85,
#  120,
#  130,
#  100,
#  60,
#  105,
#  85,
#  150,
#  90,
#  105,
#  105,
#  110,
#  90,
#  60,
#  75,
#  70,
#  80,
#  95,
#  165,
#  220,
#  135,
#  70,
#  75,
#  100,
#  85,
#  75,
#  115,
#  85,
#  95,
#  115,
#  115,
#  95,
#  310,
#  120,
#  160,
#  95,
#  100,
#  100,
#  90,
#  70,
#  90,
#  60,
#  100,
#  125,
#  145,
#  45,
#  80,
#  90,
#  120,
#  110,
#  120,
#  130,
#  120,
#  65,
#  170,
#  130,
#  105,
#  145,
#  130,
#  175,
#  95,
#  70,
#  90,
#  90,
#  150,
#  165,
#  70,
#  205,
#  115,
#  70,
#  150,
#  75,
#  100,
#  80,
#  115,
#  65,
#  100,
#  180,
#  75,
#  120,
#  65,
#  130,
#  135,
#  200,
#  130,
#  130,
#  60,
#  60,
#  75,
#  75,
#  95,
#  60,
#  205,
#  95,
#  90,
#  95,
#  80,
#  135,
#  120,
#  70,
#  85,
#  125,
#  80,
#  75,
#  105,
#  100,
#  75,
#  115,
#  80,
#  65,
#  105,
#  135,
#  150,
#  160,
#  60,
#  90,
#  65,
#  145,
#  45,
#  140,
#  135,
#  85,
#  135,
#  75,
#  135,
#  150,
#  110,
#  110,
#  80,
#  75,
#  180,
#  70,
#  120,
#  75,
#  70,
#  130,
#  110,
#  80,
#  160,
#  220,
#  110,
#  80,
#  70,
#  95,
#  195,
#  90,
#  155,
#  105,
#  75,
#  70,
#  70,
#  85,
#  185,
#  160,
#  70,
#  140,
#  80,
#  160,
#  80,
#  135,
#  80,
#  85,
#  160,
#  95,
#  95,
#  230,
#  70,
#  135,
#  75,
#  135,
#  85,
#  95,
#  90,
#  110,
#  85,
#  110,
#  155,
#  120,
#  60,
#  85,
#  85,
#  95,
#  140,
#  60,
#  240,
#  215,
#  95,
#  140,
#  155,
#  75,
#  165,
#  135,
#  60,
#  110,
#  110,
#  85,
#  60,
#  215,
#  195,
#  145,
#  130,
#  95,
#  105,
#  70,
#  105,
#  50,
#  125,
#  80,
#  75,
#  80,
#  100,
#  80,
#  45,
#  55,
#  105,
#  150,
#  75,
#  80,
#  85,
#  95,
#  220,
#  85,
#  70,
#  90,
#  80,
#  125,
#  105,
#  130,
#  140,
#  60,
#  65,
#  175,
#  65,
#  140,
#  115,
#  200,
#  150,
#  95,
#  105,
#  120,
#  40,
#  105,
#  155,
#  110,
#  55,
#  105,
#  65,
#  285,
#  140,
#  115,
#  105,
#  55,
#  65,
#  175,
#  190,
#  115,
#  105,
#  100,
#  200,
#  105,
#  85,
#  95,
#  75,
#  120,
#  185,
#  105,
#  130,
#  80,
#  60,
#  65,
#  110,
#  125,
#  55,
#  70,
#  170,
#  85,
#  105,
#  90,
#  95,
#  60,
#  100,
#  80,
#  70,
#  65,
#  150,
#  85,
#  90,
#  80,
#  80,
#  215,
#  50,
#  85,
#  180,
#  145,
#  55,
#  55,
#  65,
#  150,
#  175,
#  110,
#  85,
#  105,
#  130,
#  70,
#  75,
#  80,
#  100,
#  155,
#  125,
#  175,
#  90,
#  135,
#  75,
#  70,
#  80,
#  60,
#  175,
#  90,
#  155,
#  145,
#  95,
#  135,
#  110,
#  95,
#  105,
#  90,
#  115,
#  160,
#  140,
#  65,
#  110,
#  165,
#  85,
#  70,
#  130,
#  70,
#  90,
#  50,
#  95,
#  160,
#  140,
#  115,
#  170,
#  105,
#  120,
#  95,
#  75,
#  140,
#  135,
#  70,
#  140,
#  125,
#  120,
#  135,
#  50,
#  115,
#  105,
#  55,
#  50,
#  165,
#  90,
#  135,
#  100,
#  90,
#  190,
#  110,
#  55,
#  95,
#  110,
#  70,
#  70,
#  60,
#  110,
#  90,
#  95,
#  55,
#  85,
#  65,
#  150,
#  120,
#  65,
#  110,
#  70,
#  120,
#  120,
#  100,
#  85,
#  110,
#  145,
#  80,
#  120,
#  210,
#  55,
#  170,
#  100,
#  120,
#  75,
#  115,
#  115,
#  90,
#  100,
#  150,
#  105,
#  60,
#  85,
#  110,
#  75,
#  290,
#  60,
#  80,
#  285,
#  150,
#  185,
#  90,
#  75,
#  105,
#  80,
#  95,
#  75,
#  85,
#  115,
#  100,
#  125,
#  105,
#  75,
#  155,
#  55,
#  175,
#  100,
#  90,
#  75,
#  170,
#  100,
#  75,
#  90,
#  110,
#  130,
#  65,
#  85,
#  250,
#  125,
#  130,
#  70,
#  75,
#  190,
#  125,
#  240,
#  100,
#  180,
#  95,
#  55,
#  165,
#  100,
#  205,
#  205,
#  110,
#  60,
#  105,
#  75,
#  230,
#  90,
#  55,
#  225,
#  115,
#  100,
#  150,
#  60,
#  75,
#  170,
#  145,
#  170,
#  110,
#  115,
#  65,
#  75,
#  100,
#  85,
#  210,
#  370,
#  90,
#  100,
#  85,
#  160,
#  90,
#  75,
#  90,
#  100,
#  70,
#  195,
#  110,
#  60,
#  105,
#  85,
#  125,
#  70,
#  85,
#  60,
#  50,
#  150,
#  135,
#  110,
#  120,
#  115,
#  150,
#  85,
#  115,
#  115,
#  70,
#  85,
#  85,
#  125,
#  135,
#  45,
#  120,
#  185,
#  65,
#  105,
#  105,
#  100,
#  130,
#  50,
#  85,
#  85,
#  100,
#  75,
#  140,
#  90,
#  55,
#  125,
#  95,
#  135,
#  60,
#  95,
#  185,
#  110,
#  165,
#  95,
#  75,
#  80,
#  125,
#  65,
#  60,
#  70,
#  85,
#  70,
#  95,
#  145,
#  50,
#  100,
#  55,
#  150,
#  185,
#  65,
#  125,
#  125,
#  55,
#  65,
#  75,
#  155,
#  295,
#  145,
#  105,
#  100,
#  120,
#  100,
#  80,
#  100,
#  85,
#  100,
#  60,
#  115,
#  130,
#  85,
#  100,
#  55,
#  80,
#  105,
#  85,
#  130,
#  185,
#  105,
#  130,
#  85,
#  140,
#  90,
#  105,
#  205,
#  60,
#  160,
#  110,
#  50,
#  75,
#  80,
#  85,
#  55,
#  85,
#  145,
#  60,
#  70,
#  90,
#  70,
#  90,
#  160,
#  80,
#  85,
#  70,
#  110,
#  110,
#  50,
#  105,
#  145,
#  90,
#  105,
#  70,
#  65,
#  115,
#  80,
#  175,
#  105,
#  95,
#  75,
#  125,
#  160,
#  90,
#  85,
#  80,
#  145,
#  85,
#  90,
#  120,
#  85,
#  135,
#  140,
#  100,
#  110,
#  125,
#  75,
#  80,
#  225,
#  65,
#  110,
#  100,
#  60,
#  105,
#  130,
#  195,
#  60,
#  145,
#  90,
#  145,
#  75,
#  95,
#  175,
#  75,
#  80,
#  170,
#  100,
#  110,
#  55,
#  95,
#  110,
#  100,
#  55,
#  100,
#  95,
#  65,
#  145,
#  185,
#  60,
#  160,
#  100,
#  110,
#  110,
#  75,
#  80,
#  175,
#  125,
#  110,
#  90,
#  130,
#  90,
#  85,
#  70,
#  100,
#  115,
#  55,
#  85,
#  70,
#  100,
#  120,
#  95,
#  125,
#  180,
#  65,
#  125,
#  165,
#  150,
#  50,
#  115,
#  135,
#  150,
#  175,
#  130,
#  75,
#  265,
#  305,
#  105,
#  60,
#  60,
#  80,
#  70,
#  70,
#  90,
#  105,
#  120,
#  75,
#  95,
#  105,
#  75,
#  190,
#  125,
#  85,
#  125,
#  145,
#  55,
#  85,
#  135,
#  65,
#  165,
#  105,
#  100,
#  185,
#  65,
#  80,
#  60,
#  70,
#  60,
#  80,
#  70,
#  80,
#  70,
#  70,
#  45,
#  150,
#  100,
#  80,
#  80,
#  90,
#  65,
#  110,
#  150,
#  115,
#  170,
#  75,
#  260,
#  120,
#  195,
#  85,
#  75,
#  130,
#  105,
#  100,
#  150,
#  70,
#  145,
#  90,
#  50,
#  115,
#  95,
#  140,
#  75,
#  125,
#  135,
#  65,
#  85,
#  75,
#  130,
#  175,
#  70,
#  80,
#  90,
#  210,
#  90,
#  215,
#  70,
#  100,
#  55,
#  105,
#  65,
#  55,
#  150,
#  125,
#  145,
#  85,
#  115,
#  135,
#  230,
#  65,
#  65,
#  90,
#  105,
#  135,
#  105,
#  55,
#  40,
#  100,
#  110,
#  155,
#  45,
#  85,
#  230,
#  190,
#  170,
#  85,
#  130,
#  215,
#  75,
#  55,
#  135,
#  240,
#  85,
#  85,
#  145,
#  135,
#  85,
#  145,
#  90,
#  145,
#  80,
#  115,
#  65,
#  70,
#  105,
#  165,
#  125,
#  230,
#  105,
#  105,
#  70,
#  75,
#  85,
#  95,
#  70,
#  85,
#  110,
#  95,
#  70,
#  95,
#  215,
#  145,
#  155,
#  60,
#  115,
#  70,
#  100,
#  65,
#  160,
#  180,
#  100,
#  130,
#  85,
#  75,
#  115,
#  65,
#  85,
#  70,
#  115,
#  125,
#  80,
#  100,
#  90,
#  105,
#  55,
#  100,
#  155,
#  200,
#  195,
#  55,
#  120,
#  65,
#  85,
#  90,
#  65,
#  75,
#  60,
#  200,
#  100,
#  160,
#  70,
#  115,
#  80,
#  115,
#  80,
#  90,
#  45,
#  90]

# %%
len(pd.Series(liste)[pd.Series(liste)<100])/len(liste)
# Out:
# 0.485

# %% [markdown]
# Q2: For the Simpson's collection Problem what is the expected value for spenditure? (How many figures would you expect to buy for a complete collection?)

# %%
8*sum(1/i for i in range(1, 8+1))
# Out:
# 21.74285714285714

# %%
5*(8*sum(1/i for i in range(1,8+1)))
# Out:
# 108.7142857142857

# %%
np.random.choice(
                  sample_space,
                  p= probabilities
                )
# Out:
# 'Maggie Simpson'

# %%
collection =[]

collection.append(
                  np.random.choice(
                                  sample_space,
                                  p= probabilities
                                  )
                  )

# %%
collection =[]

while len(set(collection)) < len(sample_space):

  collection.append(
                  np.random.choice(
                                  sample_space,
                                  p= probabilities
                                  )
                  )
len(collection)
# Out:
# 22

# %%
liste = []
for i in range (10**4):
  collection = []

  while len(set(collection)) < len(sample_space):

    collection.append (
                        np.random.choice(
                                        sample_space,
                                        p = probabilities
                                        )
                        )

  liste.append(len(collection))
liste
# Out:
# [13,
#  10,
#  20,
#  32,
#  42,
#  30,
#  14,
#  13,
#  22,
#  37,
#  20,
#  18,
#  16,
#  23,
#  17,
#  22,
#  21,
#  30,
#  12,
#  24,
#  18,
#  18,
#  13,
#  20,
#  18,
#  17,
#  13,
#  21,
#  20,
#  28,
#  19,
#  11,
#  49,
#  20,
#  17,
#  25,
#  41,
#  32,
#  30,
#  11,
#  46,
#  10,
#  13,
#  22,
#  19,
#  17,
#  22,
#  31,
#  12,
#  21,
#  26,
#  15,
#  25,
#  26,
#  37,
#  10,
#  26,
#  24,
#  30,
#  33,
#  14,
#  17,
#  14,
#  20,
#  14,
#  21,
#  22,
#  19,
#  71,
#  22,
#  17,
#  17,
#  15,
#  16,
#  23,
#  11,
#  30,
#  33,
#  19,
#  17,
#  17,
#  18,
#  36,
#  23,
#  27,
#  17,
#  21,
#  18,
#  20,
#  19,
#  20,
#  19,
#  20,
#  20,
#  12,
#  14,
#  19,
#  22,
#  17,
#  19,
#  29,
#  9,
#  18,
#  15,
#  24,
#  15,
#  15,
#  22,
#  13,
#  21,
#  16,
#  14,
#  31,
#  24,
#  32,
#  13,
#  47,
#  14,
#  19,
#  12,
#  14,
#  34,
#  20,
#  19,
#  18,
#  28,
#  22,
#  35,
#  16,
#  11,
#  14,
#  27,
#  14,
#  18,
#  32,
#  27,
#  30,
#  21,
#  21,
#  23,
#  12,
#  16,
#  15,
#  26,
#  24,
#  19,
#  43,
#  14,
#  17,
#  24,
#  15,
#  16,
#  22,
#  30,
#  15,
#  24,
#  19,
#  15,
#  21,
#  16,
#  22,
#  34,
#  14,
#  15,
#  26,
#  41,
#  19,
#  18,
#  28,
#  31,
#  14,
#  22,
#  32,
#  21,
#  20,
#  24,
#  17,
#  28,
#  26,
#  10,
#  11,
#  32,
#  18,
#  15,
#  30,
#  48,
#  16,
#  12,
#  28,
#  41,
#  13,
#  31,
#  18,
#  21,
#  26,
#  38,
#  21,
#  43,
#  12,
#  18,
#  13,
#  11,
#  9,
#  16,
#  14,
#  18,
#  19,
#  33,
#  14,
#  34,
#  29,
#  17,
#  28,
#  32,
#  26,
#  11,
#  16,
#  18,
#  13,
#  22,
#  19,
#  8,
#  28,
#  22,
#  17,
#  13,
#  15,
#  35,
#  14,
#  20,
#  9,
#  12,
#  12,
#  24,
#  16,
#  42,
#  14,
#  22,
#  19,
#  24,
#  22,
#  11,
#  15,
#  27,
#  36,
#  26,
#  16,
#  20,
#  16,
#  15,
#  11,
#  19,
#  20,
#  17,
#  39,
#  21,
#  27,
#  25,
#  23,
#  17,
#  39,
#  28,
#  16,
#  34,
#  18,
#  69,
#  23,
#  18,
#  18,
#  15,
#  13,
#  28,
#  20,
#  16,
#  15,
#  18,
#  34,
#  23,
#  35,
#  17,
#  17,
#  12,
#  31,
#  20,
#  15,
#  42,
#  23,
#  25,
#  54,
#  26,
#  16,
#  16,
#  18,
#  12,
#  17,
#  25,
#  17,
#  12,
#  14,
#  34,
#  22,
#  28,
#  15,
#  19,
#  12,
#  21,
#  13,
#  18,
#  18,
#  22,
#  15,
#  12,
#  44,
#  22,
#  27,
#  14,
#  11,
#  21,
#  25,
#  10,
#  22,
#  13,
#  16,
#  49,
#  30,
#  21,
#  56,
#  30,
#  17,
#  26,
#  24,
#  17,
#  20,
#  24,
#  29,
#  33,
#  19,
#  25,
#  27,
#  12,
#  25,
#  10,
#  26,
#  18,
#  14,
#  21,
#  31,
#  15,
#  18,
#  18,
#  26,
#  19,
#  29,
#  28,
#  15,
#  13,
#  30,
#  11,
#  24,
#  13,
#  28,
#  20,
#  22,
#  24,
#  8,
#  28,
#  14,
#  13,
#  19,
#  21,
#  20,
#  24,
#  21,
#  15,
#  25,
#  12,
#  45,
#  12,
#  14,
#  14,
#  20,
#  29,
#  20,
#  17,
#  15,
#  11,
#  16,
#  24,
#  49,
#  26,
#  30,
#  10,
#  13,
#  15,
#  16,
#  35,
#  18,
#  11,
#  15,
#  37,
#  26,
#  22,
#  40,
#  25,
#  20,
#  30,
#  37,
#  16,
#  18,
#  21,
#  15,
#  21,
#  24,
#  15,
#  39,
#  21,
#  31,
#  23,
#  41,
#  20,
#  30,
#  11,
#  26,
#  17,
#  18,
#  26,
#  11,
#  20,
#  21,
#  22,
#  19,
#  12,
#  23,
#  29,
#  32,
#  23,
#  15,
#  22,
#  21,
#  12,
#  30,
#  18,
#  16,
#  27,
#  10,
#  19,
#  27,
#  12,
#  26,
#  22,
#  41,
#  27,
#  13,
#  29,
#  17,
#  19,
#  16,
#  18,
#  43,
#  16,
#  21,
#  24,
#  25,
#  12,
#  32,
#  22,
#  27,
#  46,
#  17,
#  26,
#  17,
#  17,
#  21,
#  18,
#  17,
#  16,
#  24,
#  19,
#  41,
#  19,
#  19,
#  34,
#  17,
#  25,
#  14,
#  15,
#  16,
#  40,
#  12,
#  29,
#  28,
#  20,
#  19,
#  15,
#  21,
#  16,
#  14,
#  33,
#  23,
#  19,
#  14,
#  19,
#  17,
#  15,
#  43,
#  39,
#  13,
#  24,
#  26,
#  16,
#  44,
#  18,
#  17,
#  25,
#  11,
#  11,
#  15,
#  32,
#  25,
#  14,
#  13,
#  18,
#  19,
#  12,
#  11,
#  29,
#  18,
#  24,
#  29,
#  19,
#  12,
#  16,
#  21,
#  27,
#  23,
#  25,
#  18,
#  22,
#  17,
#  10,
#  12,
#  29,
#  25,
#  15,
#  20,
#  10,
#  17,
#  61,
#  42,
#  12,
#  17,
#  22,
#  13,
#  20,
#  20,
#  21,
#  23,
#  28,
#  13,
#  13,
#  16,
#  36,
#  14,
#  13,
#  14,
#  31,
#  22,
#  42,
#  23,
#  20,
#  30,
#  29,
#  25,
#  22,
#  29,
#  18,
#  16,
#  26,
#  27,
#  25,
#  21,
#  23,
#  20,
#  22,
#  18,
#  24,
#  30,
#  19,
#  12,
#  20,
#  30,
#  29,
#  45,
#  18,
#  22,
#  12,
#  19,
#  26,
#  41,
#  28,
#  27,
#  17,
#  29,
#  20,
#  21,
#  15,
#  29,
#  19,
#  16,
#  14,
#  22,
#  29,
#  16,
#  20,
#  17,
#  58,
#  13,
#  11,
#  13,
#  22,
#  15,
#  25,
#  23,
#  23,
#  25,
#  31,
#  45,
#  14,
#  26,
#  15,
#  37,
#  35,
#  26,
#  22,
#  22,
#  18,
#  15,
#  17,
#  13,
#  21,
#  16,
#  15,
#  18,
#  31,
#  20,
#  34,
#  16,
#  19,
#  19,
#  12,
#  19,
#  13,
#  11,
#  18,
#  15,
#  18,
#  32,
#  10,
#  46,
#  14,
#  28,
#  19,
#  19,
#  13,
#  31,
#  22,
#  18,
#  17,
#  18,
#  10,
#  24,
#  38,
#  19,
#  27,
#  30,
#  18,
#  21,
#  23,
#  12,
#  38,
#  24,
#  28,
#  18,
#  24,
#  25,
#  28,
#  26,
#  22,
#  22,
#  24,
#  31,
#  27,
#  24,
#  23,
#  26,
#  22,
#  20,
#  14,
#  25,
#  17,
#  20,
#  11,
#  13,
#  17,
#  19,
#  14,
#  15,
#  39,
#  18,
#  12,
#  26,
#  50,
#  27,
#  49,
#  18,
#  26,
#  28,
#  13,
#  20,
#  33,
#  25,
#  35,
#  30,
#  30,
#  16,
#  17,
#  19,
#  27,
#  25,
#  27,
#  12,
#  31,
#  30,
#  17,
#  45,
#  42,
#  10,
#  22,
#  15,
#  15,
#  28,
#  27,
#  26,
#  9,
#  26,
#  13,
#  21,
#  28,
#  20,
#  20,
#  10,
#  29,
#  16,
#  33,
#  31,
#  18,
#  10,
#  23,
#  23,
#  19,
#  46,
#  22,
#  21,
#  33,
#  39,
#  15,
#  23,
#  20,
#  13,
#  19,
#  24,
#  29,
#  20,
#  15,
#  14,
#  16,
#  17,
#  29,
#  12,
#  23,
#  11,
#  17,
#  28,
#  11,
#  21,
#  30,
#  23,
#  21,
#  15,
#  20,
#  20,
#  12,
#  19,
#  19,
#  19,
#  25,
#  22,
#  22,
#  39,
#  18,
#  12,
#  18,
#  11,
#  16,
#  17,
#  41,
#  24,
#  13,
#  20,
#  17,
#  11,
#  23,
#  14,
#  22,
#  20,
#  23,
#  28,
#  24,
#  11,
#  24,
#  13,
#  21,
#  30,
#  12,
#  26,
#  17,
#  15,
#  31,
#  23,
#  16,
#  19,
#  12,
#  27,
#  14,
#  19,
#  41,
#  23,
#  17,
#  27,
#  15,
#  26,
#  10,
#  21,
#  24,
#  15,
#  13,
#  26,
#  11,
#  15,
#  21,
#  20,
#  11,
#  28,
#  19,
#  24,
#  10,
#  22,
#  16,
#  20,
#  16,
#  13,
#  37,
#  30,
#  27,
#  34,
#  25,
#  29,
#  13,
#  11,
#  18,
#  20,
#  28,
#  26,
#  28,
#  14,
#  18,
#  30,
#  32,
#  23,
#  22,
#  17,
#  39,
#  37,
#  16,
#  14,
#  25,
#  16,
#  15,
#  17,
#  45,
#  9,
#  17,
#  22,
#  25,
#  18,
#  17,
#  18,
#  14,
#  20,
#  29,
#  18,
#  15,
#  13,
#  23,
#  17,
#  21,
#  19,
#  30,
#  24,
#  12,
#  13,
#  31,
#  26,
#  24,
#  15,
#  25,
#  23,
#  17,
#  27,
#  17,
#  15,
#  22,
#  19,
#  16,
#  23,
#  22,
#  39,
#  16,
#  32,
#  13,
#  16,
#  54,
#  24,
#  25,
#  47,
#  21,
#  15,
#  24,
#  21,
#  30,
#  12,
#  10,
#  44,
#  28,
#  17,
#  20,
#  13,
#  28,
#  33,
#  37,
#  13,
#  22,
#  15,
#  12,
#  31,
#  24,
#  33,
#  24,
#  76,
#  27,
#  14,
#  28,
#  17,
#  17,
#  19,
#  17,
#  20,
#  18,
#  27,
#  16,
#  10,
#  52,
#  16,
#  26,
#  19,
#  16,
#  41,
#  12,
#  25,
#  27,
#  13,
#  23,
#  12,
#  13,
#  25,
#  19,
#  12,
#  9,
#  12,
#  16,
#  29,
#  16,
#  13,
#  28,
#  15,
#  14,
#  28,
#  26,
#  16,
#  17,
#  ...]

# %%
pd.Series(liste).mean()
# Out:
# 21.6636

# %%
from seaborn import histplot
histplot(pd.Series(liste))
# Out:
# <Axes: ylabel='Count'>

# %% [markdown]
# a typical F distribution

# %% [markdown]
# Q3: After buying a number of Simpson figures you figured out that the figures are not equally likely and you expect the probabilities as
#
# *   Homer Simpson : 2/20
# *   Marge Simpson: 2/20
# *   Bart Simpson: 7/20
# *   Lisa Simpson: 2/20
# *   Maggie Simpson: 1/20
# *   Ned Flanders: 2/20
# *   Milhouse Van Houten: 2/20
# *   Montgomery Burns: 2/20
#
# What is the probability that one completes the set after spending $300?

# %%
probabilities = [2/20, 2/20, 7/20, 2/20, 1/20, 2/20, 2/20, 2/20]
np.random.choice(
                  sample_space,
                  p=probabilities
                )
# Out:
# 'Milhouse Van Houten'

# %%
collection = []

while len(set(collection)) < len(sample_space):
  collection.append(
                  np.random.choice(
                                    sample_space,
                                    p=probabilities
                                  )
                  )
5*len(collection)
# Out:
# 180

# %%
liste = []

for i in range (10**4):
    collection = []

    while len(set(collection)) < len(sample_space):
      collection.append(
                        np.random.choice(
                                        sample_space,
                                        p=probabilities
                                        )
                        )
    liste.append(5*len(collection))

# %%
len(pd.Series(liste)[pd.Series(liste)>= 300]) / len(liste)
# Out:
# 0.060051

# %% [markdown]
# Q4: Jack owns a pair of biased dice. The probability of getting a number on this dice is proportional to the number itself. Jack runs a bet company and who collects all the sums from 2 to 12 before 20/50/100 rolls win.
#
# What is the probability that Jack wins instead of a customer?
